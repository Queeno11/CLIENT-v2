# %%
import numpy as np
import xarray as xr
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import seaborn as sns

PATH = "Z:\Laboral\World Bank\CLIENT v2"
DATA_RAW = rf"{PATH}\Data\Data_raw"
DATA_PROC = rf"{PATH}\Data\Data_processed"
DATA_OUT = rf"{PATH}\Data\Data_out"
ERA5 = rf"Z:\WB Data\ERA5 Reanalysis\dialy"

# %% [markdown]
# # Dialy to Monthly

# %%
# !py -m pip install cfgrib
# Out:
# Requirement already satisfied: cfgrib in c:\users\ofici\appdata\local\programs\python\python311\lib\site-packages (0.9.10.4)
# Requirement already satisfied: attrs>=19.2 in c:\users\ofici\appdata\local\programs\python\python311\lib\site-packages (from cfgrib) (23.1.0)
# Requirement already satisfied: click in c:\users\ofici\appdata\local\programs\python\python311\lib\site-packages (from cfgrib) (8.1.6)
# Requirement already satisfied: eccodes>=0.9.8 in c:\users\ofici\appdata\local\programs\python\python311\lib\site-packages (from cfgrib) (1.6.0)
# Requirement already satisfied: numpy in c:\users\ofici\appdata\local\programs\python\python311\lib\site-packages (from cfgrib) (1.24.3)
# Requirement already satisfied: cffi in c:\users\ofici\appdata\local\programs\python\python311\lib\site-packages (from eccodes>=0.9.8->cfgrib) (1.15.1)
# Requirement already satisfied: findlibs in c:\users\ofici\appdata\local\programs\python\python311\lib\site-packages (from eccodes>=0.9.8->cfgrib) (0.0.5)
# Requirement already satisfied: colorama in c:\users\ofici\appdata\roaming\python\python311\site-packages (from click->cfgrib) (0.4.6)
# Requirement already satisfied: pycparser in c:\users\ofici\appdata\local\programs\python\python311\lib\site-packages (from cffi->eccodes>=0.9.8->cfgrib) (2.21)
# [notice] A new release of pip is available: 23.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import xarray as xr

xr.open_dataset("Z:\WB Data\ERA5 Reanalysis\monthly\data_1970.zip")
# Out:
# <xarray.Dataset> Size: 399MB
# Dimensions:    (longitude: 1440, latitude: 721, time: 12)
# Coordinates:
#   * longitude  (longitude) float32 6kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#   * latitude   (latitude) float32 3kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#   * time       (time) datetime64[ns] 96B 1970-01-01 1970-02-01 ... 1970-12-01
# Data variables:
#     d2m        (time, latitude, longitude) float64 100MB ...
#     t2m        (time, latitude, longitude) float64 100MB ...
#     sp         (time, latitude, longitude) float64 100MB ...
#     tp         (time, latitude, longitude) float64 100MB ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-05-13 20:50:35 GMT by grib_to_netcdf-2.28.1: /opt/ecmw...
